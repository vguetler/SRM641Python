# %% [markdown]
# # 2-SRM 641 Week 3 Pandas

# %% [markdown]
# ## Making Pandas DataFrames from API Requests
#
# Many websites have public APIs providing data feeds via JSON or some other format. There are a number of ways to access these APIs from Python; one method recommended is the requests package, which can be installed with pip or conda: `conda install requests`
#
# In this example, we will use the U.S. Geological Survey's API to grab a JSON object of earthquake data and convert it to a `pandas.DataFrame`.
#
# USGS API: https://earthquake.usgs.gov/fdsnws/event/1/
#
# **Run the following codes and save the data in your folder for further analysis**

# %%
# Get Data from API

import datetime as dt
import pandas as pd
import requests

yesterday = dt.date.today() - dt.timedelta(days=1)
api = 'https://earthquake.usgs.gov/fdsnws/event/1/query'
payload = {
    'format': 'geojson',
    'starttime': yesterday - dt.timedelta(days=30),
    'endtime': yesterday
}
response = requests.get(api, params=payload)

# let's make sure the request was OK
response.status_code
# Out:
# 200

# %% [markdown]
# Response of 200 means OK, so we can pull the data out of the result. Since we asked the API for a JSON payload, we can extract it from the response with the json() method.

# %% [markdown]
# ## Isolate the Data from the JSON Response
#
# We need to check the structures of the response data to know where our data is.

# %%
earthquake_json = response.json()
earthquake_json.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %% [markdown]
# The USGS API provides information about our request in the metadata key. Note that your result will be different, regardless of the date range you chose, because the API includes a timestamp for when the data was pulled:

# %%
earthquake_json['metadata']
# Out:
# {'generated': 1699835425000,
#  'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2023-10-12&endtime=2023-11-11',
#  'title': 'USGS Earthquakes',
#  'status': 200,
#  'api': '1.14.0',
#  'count': 10087}

# %% [markdown]
# Each element in the JSON array features is a row of data for our dataframe.

# %%
type(earthquake_json['features'])
# Out:
# list

# %% [markdown]
# Since the results retrieved are based on real-time data, your data will be different depending on the date you run this.

# %%
earthquake_json['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.6,
#   'place': '5 km SSE of Reykjanesbær, Iceland',
#   'time': 1699659700951,
#   'updated': 1699662479040,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000la96',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000la96&format=geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 326,
#   'net': 'us',
#   'code': '7000la96',
#   'ids': ',us7000la96,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': 47,
#   'dmin': 0.943,
#   'rms': 0.37,
#   'gap': 111,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.6 - 5 km SSE of Reykjanesbær, Iceland'},
#  'geometry': {'type': 'Point', 'coordinates': [-22.5005, 63.958, 10]},
#  'id': 'us7000la96'}

# %% [markdown]
# ## Convert to DataFrame
#
# We need to grab the properties section out of every entry in the features JSON array to create our dataframe.

# %%
earthquake_properties_data = [
    quake['properties'] for quake in earthquake_json['features']
]
df = pd.DataFrame(earthquake_properties_data)
df.head() # only selected the first 5
# Out:
#     mag                              place           time        updated  \
# 0  4.60  5 km SSE of Reykjanesbær, Iceland  1699659700951  1699662479040
# 1 -0.17                   Alaska Peninsula  1699659556140  1699668903770
# 2  4.50                          Banda Sea  1699658997006  1699660514040
# 3  3.15  4 km WSW of Mayagüez, Puerto Rico  1699657949680  1699659717050
# 4  1.10     31 km SSW of Goldfield, Nevada  1699656768354  1699659341711
#
#      tz                                                url  \
# 0  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#             ids sources                types   nst     dmin     rms     gap  \
# 0  ,us7000la96,    ,us,  ,origin,phase-data,  47.0  0.94300  0.3700  111.00
# 1  ,av91121313,    ,av,  ,origin,phase-data,   6.0      NaN  0.0500  147.00
# 2  ,us7000la90,    ,us,  ,origin,phase-data,  29.0  1.57000  0.8200   54.00
# 3  ,pr71431213,    ,pr,  ,origin,phase-data,  10.0  0.04183  0.1900  157.00
# 4  ,nn00868762,    ,nn,  ,origin,phase-data,  10.0  0.18400  0.1333  122.75
#
#   magType        type                                      title
# 0      mb  earthquake  M 4.6 - 5 km SSE of Reykjanesbær, Iceland
# 1      ml  earthquake                  M -0.2 - Alaska Peninsula
# 2      mb  earthquake                          M 4.5 - Banda Sea
# 3      md  earthquake  M 3.2 - 4 km WSW of Mayagüez, Puerto Rico
# 4      ml  earthquake     M 1.1 - 31 km SSW of Goldfield, Nevada
#
# [5 rows x 26 columns]

# %%
# View the whole dataframe, has 10087 rows, 26 columns

df
# Out:
#         mag                              place           time        updated  \
# 0      4.60  5 km SSE of Reykjanesbær, Iceland  1699659700951  1699662479040
# 1     -0.17                   Alaska Peninsula  1699659556140  1699668903770
# 2      4.50                          Banda Sea  1699658997006  1699660514040
# 3      3.15  4 km WSW of Mayagüez, Puerto Rico  1699657949680  1699659717050
# 4      1.10     31 km SSW of Goldfield, Nevada  1699656768354  1699659341711
# ...     ...                                ...            ...            ...
# 10082  0.95        3 km ENE of The Geysers, CA  1697069851600  1697077996330
# 10083  1.12        3 km ENE of The Geysers, CA  1697069809590  1697076372183
# 10084  1.40       115 km NW of Yakutat, Alaska  1697069804213  1698690566413
# 10085  1.03               3 km SSW of Cobb, CA  1697069373120  1697072892830
# 10086  0.90            24 km ESE of Julian, CA  1697068830650  1697131563986
#
#          tz                                                url  \
# 0      None  https://earthquake.usgs.gov/earthquakes/eventp...
# 1      None  https://earthquake.usgs.gov/earthquakes/eventp...
# 2      None  https://earthquake.usgs.gov/earthquakes/eventp...
# 3      None  https://earthquake.usgs.gov/earthquakes/eventp...
# 4      None  https://earthquake.usgs.gov/earthquakes/eventp...
# ...     ...                                                ...
# 10082  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 10083  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 10084  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 10085  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 10086  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail  felt  cdi  mmi  ...  \
# 0      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 1      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 2      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 3      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 4      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# ...                                                  ...   ...  ...  ...  ...
# 10082  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  0.0  NaN  ...
# 10083  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10084  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10085  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10086  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#                   ids sources  \
# 0        ,us7000la96,    ,us,
# 1        ,av91121313,    ,av,
# 2        ,us7000la90,    ,us,
# 3        ,pr71431213,    ,pr,
# 4        ,nn00868762,    ,nn,
# ...               ...     ...
# 10082    ,nc73946215,    ,nc,
# 10083    ,nc73946210,    ,nc,
# 10084  ,ak023d3c9fpb,    ,ak,
# 10085    ,nc73946205,    ,nc,
# 10086    ,ci40581440,    ,ci,
#
#                                                    types   nst     dmin  \
# 0                                    ,origin,phase-data,  47.0  0.94300
# 1                                    ,origin,phase-data,   6.0      NaN
# 2                                    ,origin,phase-data,  29.0  1.57000
# 3                                    ,origin,phase-data,  10.0  0.04183
# 4                                    ,origin,phase-data,  10.0  0.18400
# ...                                                  ...   ...      ...
# 10082  ,dyfi,nearby-cities,origin,phase-data,scitech-...   8.0  0.01036
# 10083     ,nearby-cities,origin,phase-data,scitech-link,   9.0  0.01018
# 10084                                ,origin,phase-data,   NaN      NaN
# 10085     ,nearby-cities,origin,phase-data,scitech-link,  16.0  0.01684
# 10086     ,nearby-cities,origin,phase-data,scitech-link,  35.0  0.07059
#
#           rms     gap magType        type  \
# 0      0.3700  111.00      mb  earthquake
# 1      0.0500  147.00      ml  earthquake
# 2      0.8200   54.00      mb  earthquake
# 3      0.1900  157.00      md  earthquake
# 4      0.1333  122.75      ml  earthquake
# ...       ...     ...     ...         ...
# 10082  0.0200   92.00      md  earthquake
# 10083  0.0100   92.00      md  earthquake
# 10084  0.4200     NaN      ml   ice quake
# 10085  0.0300  107.00      md  earthquake
# 10086  0.1900   71.00      ml  earthquake
#
#                                                 title
# 0           M 4.6 - 5 km SSE of Reykjanesbær, Iceland
# 1                           M -0.2 - Alaska Peninsula
# 2                                   M 4.5 - Banda Sea
# 3           M 3.2 - 4 km WSW of Mayagüez, Puerto Rico
# 4              M 1.1 - 31 km SSW of Goldfield, Nevada
# ...                                               ...
# 10082             M 1.0 - 3 km ENE of The Geysers, CA
# 10083             M 1.1 - 3 km ENE of The Geysers, CA
# 10084  M 1.4 Ice Quake - 115 km NW of Yakutat, Alaska
# 10085                    M 1.0 - 3 km SSW of Cobb, CA
# 10086                 M 0.9 - 24 km ESE of Julian, CA
#
# [10087 rows x 26 columns]

# %%
# View the last 5 observations

df.tail()
# Out:
#         mag                         place           time        updated    tz  \
# 10082  0.95   3 km ENE of The Geysers, CA  1697069851600  1697077996330  None
# 10083  1.12   3 km ENE of The Geysers, CA  1697069809590  1697076372183  None
# 10084  1.40  115 km NW of Yakutat, Alaska  1697069804213  1698690566413  None
# 10085  1.03          3 km SSW of Cobb, CA  1697069373120  1697072892830  None
# 10086  0.90       24 km ESE of Julian, CA  1697068830650  1697131563986  None
#
#                                                      url  \
# 10082  https://earthquake.usgs.gov/earthquakes/eventp...
# 10083  https://earthquake.usgs.gov/earthquakes/eventp...
# 10084  https://earthquake.usgs.gov/earthquakes/eventp...
# 10085  https://earthquake.usgs.gov/earthquakes/eventp...
# 10086  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail  felt  cdi  mmi  ...  \
# 10082  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  0.0  NaN  ...
# 10083  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10084  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10085  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 10086  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#                   ids sources  \
# 10082    ,nc73946215,    ,nc,
# 10083    ,nc73946210,    ,nc,
# 10084  ,ak023d3c9fpb,    ,ak,
# 10085    ,nc73946205,    ,nc,
# 10086    ,ci40581440,    ,ci,
#
#                                                    types   nst     dmin   rms  \
# 10082  ,dyfi,nearby-cities,origin,phase-data,scitech-...   8.0  0.01036  0.02
# 10083     ,nearby-cities,origin,phase-data,scitech-link,   9.0  0.01018  0.01
# 10084                                ,origin,phase-data,   NaN      NaN  0.42
# 10085     ,nearby-cities,origin,phase-data,scitech-link,  16.0  0.01684  0.03
# 10086     ,nearby-cities,origin,phase-data,scitech-link,  35.0  0.07059  0.19
#
#          gap magType        type  \
# 10082   92.0      md  earthquake
# 10083   92.0      md  earthquake
# 10084    NaN      ml   ice quake
# 10085  107.0      md  earthquake
# 10086   71.0      ml  earthquake
#
#                                                 title
# 10082             M 1.0 - 3 km ENE of The Geysers, CA
# 10083             M 1.1 - 3 km ENE of The Geysers, CA
# 10084  M 1.4 Ice Quake - 115 km NW of Yakutat, Alaska
# 10085                    M 1.0 - 3 km SSW of Cobb, CA
# 10086                 M 0.9 - 24 km ESE of Julian, CA
#
# [5 rows x 26 columns]

# %% [markdown]
# Using DataFrame’s `to_csv` method, we can write the data out to a comma-separated file:

# %%
# Write to csv - save in your folder

df.to_csv('earthquakes.csv', index=False)

# %% [markdown]
# Resources:
#
# - Stefanie Molin. Hands on Data Analysis with Pandas
